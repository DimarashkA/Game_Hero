# %% [markdown]
# <a href="https://colab.research.google.com/github/DimarashkA/Game_Hero/blob/main/HW_AZ01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Задание №1

# %%
# Загрузка библиотеки pandas
import pandas as pd

# %%
# Загрузка набора данных из CSV-файла в DataFrame:
df = pd.read_csv('/content/drive/MyDrive/Zerocoder/four_sessions.csv')

# %%
# Вывод первых 5 строк данных:
df.head(5)
# Out:
#      Page  Time
# 0  Page 1   164
# 1  Page 2   178
# 2  Page 3   175
# 3  Page 4   155
# 4  Page 1   172

# %%
# Информация о данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Page    20 non-null     object
#  1   Time    20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
# Статистическое описание данных
df.describe()
# Out:
#              Time
# count   20.000000
# mean   173.900000
# std     11.355036
# min    155.000000
# 25%    165.500000
# 50%    173.500000
# 75%    179.000000
# max    195.000000

# %% [markdown]
# ##Задание №2

# %%
# Загрузка набора данных из CSV-файла в DataFrame:
df = pd.read_csv('/content/drive/MyDrive/Zerocoder/dz.csv')

# %%
# Вывод первых строк данных:
df.head()
# Out:
#     Name    City    Salary
# 0    Аня   Томск  200000.0
# 1    Боб  Москва  350000.0
# 2  Чарли  Москва  270000.0
# 3   Лиза   Томск   70000.0
# 4  Настя     NaN   35000.0

# %%
#Определение средней зарплаты (Salary) по городу (City)
average_salary_by_city = df.groupby('City')['Salary'].mean()

print(average_salary_by_city)
# Out:
# City
# Москва    211400.0
# Томск      91250.0
# Name: Salary, dtype: float64
